# %% [markdown]
# # Reading mater drug file and creating dictionary

# %%
import pandas as pd

# %%
pwd
# Out:
# '/home/sunil.patel/PycharmProjects/jaankijaan/data_augmantation/data'

# %%
df = pd.read_csv("out_unique_final.csv", sep="ж")
# Out:
# /home/sunil.patel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the separator encoded in utf-8 is > 1 char long, and the 'c' engine does not support such separators; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#         S/N                                       Manufacturer  \
# 0         1                                       Jan Aushadhi
# 1         2                               Bombay Tablet Mfg Co
# 2         3                Bestochem Formulations (India) Ltd.
# 3         4                                 Alpic Biotech Ltd.
# 4         5                             Alkem Laboratories Ltd
# 5         6                  Aaron Healthcare & Export Pvt.Ltd
# 6         7            Milieus (Glenmark Pharmaceuticals Ltd.)
# 7         8                         Welcure Drugs & Pharma Ltd
# 8         9                             Wisdom Pharma Pvt. Ltd
# 9        10                           Nodysis Pharma Pvt. Ltd.
# 10       11                                  Abbott India Ltd.
# 11       12                                Profic Organic Ltd.
# 12       13                                       Aglowmed Ltd
# 13       14                              Acron Pharmaceuticals
# ...

# %%
df.columns
# Out:
# Index(['S/N', 'Manufacturer', 'Name', 'Type', 'Unit(Dose)',
#        'Constituents/Unit', 'Package unit', 'Price(In Rs.)',
#        'Price/Unit (In Rs.)'],
#       dtype='object')

# %%
new = df["Constituents/Unit"].str.split("-", n = 1, expand = False)

# %%
df['Constituents'] = new[0]
df['Unit'] = new[1]

# %%
 df
# Out:
#         S/N                                       Manufacturer  \
# 0         1                                       Jan Aushadhi
# 1         2                               Bombay Tablet Mfg Co
# 2         3                Bestochem Formulations (India) Ltd.
# 3         4                                 Alpic Biotech Ltd.
# 4         5                             Alkem Laboratories Ltd
# 5         6                  Aaron Healthcare & Export Pvt.Ltd
# 6         7            Milieus (Glenmark Pharmaceuticals Ltd.)
# 7         8                         Welcure Drugs & Pharma Ltd
# 8         9                             Wisdom Pharma Pvt. Ltd
# 9        10                           Nodysis Pharma Pvt. Ltd.
# 10       11                                  Abbott India Ltd.
# 11       12                                Profic Organic Ltd.
# 12       13                                       Aglowmed Ltd
# 13       14                              Acron Pharmaceuticals
# ...
